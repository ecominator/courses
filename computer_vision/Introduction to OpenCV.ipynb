# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
cv2.__version__
# Out:
# '4.6.0'

# %%
img = cv2.imread("dog.jpg")
img
# Out:
# array([[[ 79, 114, 128],
#         [ 72, 107, 120],
#         [ 67,  99, 112],
#         ...,
#         [ 27,  27,  39],
#         [ 29,  31,  42],
#         [ 28,  32,  43]],
#
#        [[ 80, 115, 129],
#         [ 73, 108, 121],
#         [ 68, 103, 113],
#         ...,
#         [ 31,  33,  44],
#         [ 32,  36,  47],
#         [ 30,  36,  47]],
#
#        [[ 77, 115, 127],
#         [ 72, 110, 122],
#         [ 67, 106, 115],
#         ...,
#         [ 31,  40,  50],
#         [ 25,  34,  44],
#         [ 25,  34,  44]],
#
#        ...,
#
#        [[ 98, 170, 164],
#         [ 94, 166, 160],
#         [ 90, 162, 156],
#         ...,
#         [ 54, 125, 115],
#         [ 51, 125, 113],
#         [ 50, 127, 113]],
#
#        [[ 96, 170, 164],
#         [ 92, 166, 160],
#         [ 91, 163, 157],
#         ...,
#         [ 52, 121, 111],
#         [ 51, 124, 114],
#         [ 50, 126, 114]],
#
#        [[ 97, 171, 165],
#         [ 92, 166, 160],
#         [ 91, 163, 157],
# ...

# %%
cv2.imshow("Dog Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("dog.jpg", 0) #0 is for gray scale conversion. it is by default 1 and it gives RGB
cv2.imshow("Dog Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("saved_dog_image.jpg", img)
# Out:
# True

# %% [markdown]
# Changing Color Spaces

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Dog Image", gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2.imshow("HSV Dog Image", hsv_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Drawing with CV2

# %%
cv2.line(img, (0,0),(400,400),(255,0,0),5) #color of line, thickness of line
cv2.imshow("Line on dog", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
cv2.circle(img, (100,50),10,(255,0,0),3) #location, radius, color, thickness
cv2.imshow("Circle on dog", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.putText(img,"A dog", (50,200), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 5)
plt.imshow(img)

# %% [markdown]
# Callback & Tracebars

# %%
black_img = np.zeros((512, 512, 3), np.uint8)
cv2.namedWindow("Black Image")

def draw_circle(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(black_img, (x,y), 50, (255,50,70), 5)
        
cv2.setMouseCallback('Black Image', draw_circle)
while(1):
    cv2.imshow('Black Image', black_img)
    k = cv2.waitKey(5)
    if k == 27:
        break
    
cv2.destroyAllWindows()

# %%
cv2.namedWindow("Image")

cv2.createTrackbar('Channel', 'Image', 0, 2, lambda x:print(x))

while(1):
    v = cv2.getTrackbarPos('Channel', 'Image')
    cv2.imshow('Image', img[:,:,v])
    k = cv2.waitKey(5)
    if k == 27:
        break
        
cv2.destroyAllWindows()
# Out:
# 1
# 2
# 1
# 0
# 1
# 2
# 1
# 0
# 1
# 2
# 1
# 0
# 1
# 2
# 1
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [38], in <cell line: 6>()
#       3 cv2.createTrackbar('Channel', 'Image', 0, 2, lambda x:print(x))
#       5 while(1):
# ----> 6     v = cv2.getTrackbarPos('Channel', 'Image')
#       7     cv2.imshow('Image', img[:,:,v])
#       8     k = cv2.waitKey(5)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2581: error: (-27:Null pointer) NULL window: 'Image' in function 'cvGetTrackbarPos'

# %% [markdown]
# Basic Image Operations

# %%
px = img[100,150]
px
# Out:
# array([147, 212, 227], dtype=uint8)

# %%
plt.imshow(img)

# %%
px_blue = img[100,150,0] #BGR format 0 is blue
px_blue
# Out:
# 147

# %%
b = img[:,:,0]
cv2.imshow("Blue Channel", b)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
img.shape
# Out:
# (259, 194, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.size
# Out:
# 150738

# %%
face = img[20:100,20:125]
plt.imshow(face)

# %%
b,g,r = cv2.split(img)
cv2.imshow('b',b)
cv2.imshow('g',g)
cv2.imshow('r',r)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.merge((b,g,r))
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <function destroyAllWindows>

# %%
horizontal_stack = np.hstack((img,img))
plt.imshow(horizontal_stack)

# %%
vertical_stack = np.vstack((img,img))
plt.imshow(vertical_stack)

# %%
reflect = cv2.copyMakeBorder(img, 200, 200, 200, 200, cv2.BORDER_REFLECT_101)
plt.imshow(reflect)
